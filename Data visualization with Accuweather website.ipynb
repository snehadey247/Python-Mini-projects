# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hp\kolkata+june.csv")

# %%
df1=pd.read_csv(r"C:\Users\hp\kolkata+july.csv")

# %%
df
# Out:
#     Date  High_temp  Low_temp  Precipitation
# 0      1         35        23            6.0
# 1      2         37        26            6.0
# 2      3         37        26            0.0
# 3      4         37        26            6.0
# 4      5         36        25            1.0
# 5      6         37        29            0.0
# 6      7         37        26           14.0
# 7      8         37        26            4.0
# 8      9         36        27            0.0
# 9     10         35        28            0.0
# 10    11         32        28            7.0
# 11    12         30        27           41.0
# 12    13         31        27            1.0
# 13    14         30        27           24.0
# 14    15         32        26            4.0
# 15    16         34        26            3.0
# 16    17         33        27            0.0
# 17    18         33        27            0.0
# 18    19         34        27            1.0
# 19    20         34        28            2.0
# 20    21         34        27           37.0
# 21    22         34        26           17.0
# 22    23         33        27           14.0
# 23    24         36        28            0.0
# 24    25         36        28            0.0
# 25    26         36        25            3.0
# 26    27         34        25           41.0
# 27    28         35        24           12.0
# 28    29         31        24            4.0
# 29    30         35        27            2.0

# %%
df1
# Out:
#     Date  High_temp  Low_temp  Precipitation
# 0      1         36        28            0.0
# 1      2         37        28            0.0
# 2      3         36        29            0.0
# 3      4         35        28            0.0
# 4      5         32        28           21.0
# 5      6         33        27            3.0
# 6      7         33        27            7.0
# 7      8         36        28            0.0
# 8      9         35        28           10.0
# 9     10         35        28            0.0
# 10    11         35        26           27.0
# 11    12         35        26           33.0
# 12    13         33        25            4.0
# 13    14         35        28            1.0
# 14    15         34        27            4.0
# 15    16         34        26            6.0
# 16    17         34        27            0.0
# 17    18         36        28            0.0
# 18    19         35        27            8.0
# 19    20         34        27           18.0
# 20    21         32        25           23.0
# 21    22         31        25            4.0
# 22    23         28        24           56.0
# 23    24         32        27            0.0
# 24    25         35        26            0.0
# 25    26         36        28            0.0
# 26    27         35        28            6.0
# 27    28         35        27           29.0
# 28    29         33        25           50.0
# 29    30         35        27            0.0
# 30    31         36        28            5.0

# %%
#Plotting the line chart of Date vs High Temperature


plt.plot(df['Date'],df['High_temp'])


plt.title("Date vs High Temperature",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temp. in degree celcius",fontsize=15)
# Out:
# Text(0, 0.5, 'High Temp. in degree celcius')

# %%
#Plotting the line chart of Date vs Low Temperature

plt.plot(df['Date'],df['Low_temp'])


plt.title("Date vs Low Temperature",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temp. in degree celcius",fontsize=15)
# Out:
# Text(0, 0.5, 'Low Temp. in degree celcius')

# %%
#Plotting the line chart of Date vs Precipitation

plt.plot(df['Date'],df['Precipitation'])


plt.title("Date vs Precipitation",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation in mm",fontsize=15)
# Out:
# Text(0, 0.5, 'Precipitation in mm')

# %%
#Plotting the line chart of Date vs High Temperature & Date vs Low Temperature


plt.subplot(2,1,1)
plt.plot(df['Date'],df['High_temp'])


plt.title("Date vs High Temperature",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("High Temp. in degree celcius",fontsize=15)

plt.show()



plt.subplot(2,1,1)
plt.plot(df['Date'],df['Low_temp'])


plt.title("Date vs Low Temperature",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Low Temp. in degree celcius",fontsize=15)

plt.show()

# %%
#Plotting the line chart of Date vs Precipitation for Kolkata & Date vs Precipitation Mumbai.


plt.subplot(2,1,1)
plt.plot(df['Date'],df['Precipitation'])


plt.title("Kolkata",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation",fontsize=15)

plt.show()



plt.subplot(2,1,2)
plt.plot(df1['Date'],df1['Precipitation'])


plt.title("Mumbai",fontsize=20)
plt.xlabel("Date",fontsize=15)
plt.ylabel("Precipitation",fontsize=15)

plt.show()
